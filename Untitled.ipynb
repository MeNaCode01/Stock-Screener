# %%
import datetime as dt
import pandas as pd
from pandas_datareader import data as pdr
import matplotlib.pyplot as plt
import yfinance as yf
from tkinter import Tk
from tkinter.filedialog import askopenfilename
import os
from pandas import ExcelWriter
import yahoo_fin.stock_info as si

yf.pdr_override() 
start =dt.datetime(2010,12,1)
now = dt.datetime.now()

# root = Tk()
# ftypes = [(".xlsm","*.xlsx",".xls")]
# ttl  = "Title"
# dir1 = 'C:\\'
# filePath = askopenfilename(filetypes = ftypes, initialdir = dir1, title = ttl)
filePath=r"C:\Users\MANAV\Desktop\ind_nifty50list.xlsx"

stocklist = pd.read_excel(filePath)
# stocklist=stocklist.head()

exportList= pd.DataFrame(columns=['Stock', "50 Day MA", "150 Day Ma", "200 Day MA", "52 Week Low", "52 week High"])

for i in stocklist.index:
    stock=str(stocklist["Symbol"][i])

    try:
        df = pdr.get_data_yahoo(f'{stock}.NS', start, now)
        print(stock)

        smaUsed=[50,150,200]
        for x in smaUsed:
            sma=x
            df['SMA_' + str(sma)] = round(df.Close.rolling(window = sma).mean())


        currentClose=df["Adj Close"][-1]
        moving_average_50=df["SMA_50"][-1]
        moving_average_150=df["SMA_150"][-1]
        moving_average_200=df["SMA_200"][-1]
        low_of_52week=min(df["Adj Close"][-260:])
        high_of_52week=max(df["Adj Close"][-260:])
        try:
            moving_average_200_20 = df["SMA_200"][-20]

        except Exception:
            moving_average_200_20=0

#         plt.figure(figsize=(12,6))
#         plt.plot(df.Close, label="Closing Price", color="green")
#         plt.plot(df.SMA_150, label="SMA_150", color="b")
#         plt.plot(df.SMA_200, label="SMA_200", color="r")
#         plt.legend()
#         plt.xlabel("YEARS")
#         plt.ylabel("PRICE")
#         plt.title(exportList.Stock[0])

        #Condition 1: Current Price > 150 SMA and > 200 SMA
        if(currentClose>moving_average_150>moving_average_200):
            cond_1=True
        else:
            cond_1=False
        #Condition 2: 150 SMA and > 200 SMA
        if(moving_average_150>moving_average_200):
            cond_2=True
        else:
            cond_2=False
        #Condition 3: 200 SMA trending up for at least 1 month (ideally 4-5 months)
        if(moving_average_200>moving_average_200_20):
            cond_3=True
        else:
            cond_3=False
        #Condition 4: 50 SMA> 150 SMA and 50 SMA> 200 SMA
        if(moving_average_50>moving_average_150>moving_average_200):
        #print("Condition 4 met")
            cond_4=True
        else:
        #print("Condition 4 not met")
            cond_4=False
        #Condition 5: Current Price > 50 SMA
        if(currentClose>moving_average_50):
            cond_5=True
        else:
            cond_5=False
        #Condition 6: Current Price is at least 30% above 52 week low (Many of the best are up 100-300% before coming out of consolidation)
        if(currentClose>=(1.3*low_of_52week)):
            cond_6=True
        else:
            cond_6=False
        #Condition 7: Current Price is within 25% of 52 week high
        if(currentClose>=(.75*high_of_52week)):
            cond_7=True
        else:
            cond_7=False

        if(cond_1 and cond_2 and cond_3 and cond_4 and cond_5 and cond_6 and cond_7):
            exportList = exportList.append({'Stock': stock, "50 Day MA": moving_average_50, "150 Day Ma": moving_average_150, "200 Day MA": moving_average_200, "52 Week Low": low_of_52week, "52 week High": high_of_52week}, ignore_index=True)
    except Exception:
        print("No data on "+stock)

print(exportList)
writer= ExcelWriter("C:\\Users\\MANAV\\Desktop\\Stock Screener\\datasource.xlsx")
df.to_excel(writer,"Sheet1")
writer.save()


for i in exportList.index:
    stock=str(exportList["Stock"][i])
#     print(stock)
#     print(i)

    try:
        df = pdr.get_data_yahoo(f'{stock}.NS', start, now)

        smaUsed=[50,150,200]
        for e, x in enumerate(smaUsed):
            sma=x
            df['SMA_' + str(sma)] = round(df.Close.rolling(window = sma).mean())


        currentClose=df["Adj Close"][-1]
        moving_average_50=df["SMA_50"][-1]
        moving_average_150=df["SMA_150"][-1]
        moving_average_200=df["SMA_200"][-1]
        low_of_52week=min(df["Adj Close"][-260:])
        high_of_52week=max(df["Adj Close"][-260:])
        
        plt.figure(figsize=(12,6))
        plt.xlabel("YEARS")
        plt.ylabel("PRICE")
        plt.title(stock)
        plt.plot(df.Close, label="Closing Price", color="green")
        plt.plot(df.SMA_150, label="SMA_150", color="b")
        plt.plot(df.SMA_200, label="SMA_200", color="r")
        plt.legend()
    except Exception as e:
        print(e)

plt.show()
        
currentPrice=[]
marketCap = []
PE_Ratio = []
stocks = []

for i in exportList.index:
    stock=str(exportList["Stock"][i])
    stocks.append(stock)
    
    try:
        df1 = pdr.get_data_yahoo(f'{stock}.NS', start, now)
        currentPrice.append(df1.Close[-1])
        
        df2 = pdr.get_quote_yahoo(f'{stock}.NS')['marketCap']
        marketCap.append(df2.iloc[0])
        
        stock_info = si.get_quote_table(f'{stock}.NS')
        df3 = pd.DataFrame.from_dict(stock_info,orient='index')
        PE_Ratio.append(float(df3.loc['PE Ratio (TTM)']))


    except Exception:
        print("No data on "+stock)
        
Market_Cap_in_mil = [i/100000000 for i in marketCap]



# plt.figure(len(smaUsed)+ 1, figsize=(12,6))

plt.xlabel("Stocks")
plt.ylabel("PE Ratio")
plt.title("Selected Stocks PE Ratio")
plt.bar(stocks, PE_Ratio, width=0.5, color='green')
plt.show()



plt.xlabel("Stocks")
plt.ylabel("Market Cap")
plt.title("Selected Stocks Market Cap(in Millions)")
plt.bar(stocks, Market_Cap_in_mil, width=0.5, color='green')
plt.show()


# # plt.bar(stocks, currentPrice, width=0.5, color='green')
# plt.xlabel("Stocks")
# plt.ylabel("Price")
# plt.title("Selected Stocks Price")
# Out:
# [*********************100%***********************]  1 of 1 completed
# ADANIENT
# C:\Users\MANAV\AppData\Local\Temp\ipykernel_10536\3818606084.py:101: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exportList = exportList.append({'Stock': stock, "50 Day MA": moving_average_50, "150 Day Ma": moving_average_150, "200 Day MA": moving_average_200, "52 Week Low": low_of_52week, "52 week High": high_of_52week}, ignore_index=True)
# [*********************100%***********************]  1 of 1 completed
# ADANIPORTS
# C:\Users\MANAV\AppData\Local\Temp\ipykernel_10536\3818606084.py:101: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exportList = exportList.append({'Stock': stock, "50 Day MA": moving_average_50, "150 Day Ma": moving_average_150, "200 Day MA": moving_average_200, "52 Week Low": low_of_52week, "52 week High": high_of_52week}, ignore_index=True)
# [*********************100%***********************]  1 of 1 completed
# APOLLOHOSP
# [*********************100%***********************]  1 of 1 completed
# ASIANPAINT
# [*********************100%***********************]  1 of 1 completed
# AXISBANK
# [*********************100%***********************]  1 of 1 completed
# BAJAJ-AUTO
# [*********************100%***********************]  1 of 1 completed
# BAJFINANCE
# [*********************100%***********************]  1 of 1 completed
# BAJAJFINSV
# [*********************100%***********************]  1 of 1 completed
# BPCL
# [*********************100%***********************]  1 of 1 completed
# BHARTIARTL
# C:\Users\MANAV\AppData\Local\Temp\ipykernel_10536\3818606084.py:101: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exportList = exportList.append({'Stock': stock, "50 Day MA": moving_average_50, "150 Day Ma": moving_average_150, "200 Day MA": moving_average_200, "52 Week Low": low_of_52week, "52 week High": high_of_52week}, ignore_index=True)
# [*********************100%***********************]  1 of 1 completed
# BRITANNIA
# C:\Users\MANAV\AppData\Local\Temp\ipykernel_10536\3818606084.py:101: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exportList = exportList.append({'Stock': stock, "50 Day MA": moving_average_50, "150 Day Ma": moving_average_150, "200 Day MA": moving_average_200, "52 Week Low": low_of_52week, "52 week High": high_of_52week}, ignore_index=True)
# [*********************100%***********************]  1 of 1 completed
# CIPLA
# [*********************100%***********************]  1 of 1 completed
# COALINDIA
# [*********************100%***********************]  1 of 1 completed
# DIVISLAB
# [*********************100%***********************]  1 of 1 completed
# DRREDDY
# [*********************100%***********************]  1 of 1 completed
# EICHERMOT
# [*********************100%***********************]  1 of 1 completed
# GRASIM
# [*********************100%***********************]  1 of 1 completed
# HCLTECH
# [*********************100%***********************]  1 of 1 completed
# HDFCBANK
# [*********************100%***********************]  1 of 1 completed
# HDFCLIFE
# [*********************100%***********************]  1 of 1 completed
# HEROMOTOCO
# [*********************100%***********************]  1 of 1 completed
# HINDALCO
# [*********************100%***********************]  1 of 1 completed
# HINDUNILVR
# [*********************100%***********************]  1 of 1 completed
# HDFC
# [*********************100%***********************]  1 of 1 completed
# ICICIBANK
# C:\Users\MANAV\AppData\Local\Temp\ipykernel_10536\3818606084.py:101: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exportList = exportList.append({'Stock': stock, "50 Day MA": moving_average_50, "150 Day Ma": moving_average_150, "200 Day MA": moving_average_200, "52 Week Low": low_of_52week, "52 week High": high_of_52week}, ignore_index=True)
# [*********************100%***********************]  1 of 1 completed
# ITC
# C:\Users\MANAV\AppData\Local\Temp\ipykernel_10536\3818606084.py:101: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exportList = exportList.append({'Stock': stock, "50 Day MA": moving_average_50, "150 Day Ma": moving_average_150, "200 Day MA": moving_average_200, "52 Week Low": low_of_52week, "52 week High": high_of_52week}, ignore_index=True)
# [*********************100%***********************]  1 of 1 completed
# INDUSINDBK
# [*********************100%***********************]  1 of 1 completed
# INFY
# [*********************100%***********************]  1 of 1 completed
# JSWSTEEL
# [*********************100%***********************]  1 of 1 completed
# KOTAKBANK
# [*********************100%***********************]  1 of 1 completed
# LT
# [*********************100%***********************]  1 of 1 completed
# M&M
# [*********************100%***********************]  1 of 1 completed
# MARUTI
# [*********************100%***********************]  1 of 1 completed
# NTPC
# [*********************100%***********************]  1 of 1 completed
# NESTLEIND
# [*********************100%***********************]  1 of 1 completed
# ONGC
# [*********************100%***********************]  1 of 1 completed
# POWERGRID
# [*********************100%***********************]  1 of 1 completed
# RELIANCE
# [*********************100%***********************]  1 of 1 completed
# SBILIFE
# [*********************100%***********************]  1 of 1 completed
# SBIN
# C:\Users\MANAV\AppData\Local\Temp\ipykernel_10536\3818606084.py:101: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exportList = exportList.append({'Stock': stock, "50 Day MA": moving_average_50, "150 Day Ma": moving_average_150, "200 Day MA": moving_average_200, "52 Week Low": low_of_52week, "52 week High": high_of_52week}, ignore_index=True)
# [*********************100%***********************]  1 of 1 completed
# SUNPHARMA
# C:\Users\MANAV\AppData\Local\Temp\ipykernel_10536\3818606084.py:101: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exportList = exportList.append({'Stock': stock, "50 Day MA": moving_average_50, "150 Day Ma": moving_average_150, "200 Day MA": moving_average_200, "52 Week Low": low_of_52week, "52 week High": high_of_52week}, ignore_index=True)
# [*********************100%***********************]  1 of 1 completed
# TCS
# [*********************100%***********************]  1 of 1 completed
# TATACONSUM
# [*********************100%***********************]  1 of 1 completed
# TATAMOTORS
# [*********************100%***********************]  1 of 1 completed
# TATASTEEL
# [*********************100%***********************]  1 of 1 completed
# TECHM
# [*********************100%***********************]  1 of 1 completed
# TITAN
# [*********************100%***********************]  1 of 1 completed
# UPL
# [*********************100%***********************]  1 of 1 completed
# ULTRACEMCO
# [*********************100%***********************]  1 of 1 completed
# WIPRO
#         Stock  50 Day MA  150 Day Ma  200 Day MA  52 Week Low  52 week High
# 0    ADANIENT     3550.0      2803.0      2551.0  1472.174194   4057.800049
# 1  ADANIPORTS      860.0       798.0       783.0   650.344666    970.250000
# 2  BHARTIARTL      795.0       731.0       727.0   638.063965    846.150024
# 3   BRITANNIA     3825.0      3640.0      3567.0  2995.101318   4175.350098
# 4   ICICIBANK      895.0       808.0       791.0   649.850281    926.299988
# 5         ITC      340.0       302.0       286.0   202.271790    360.700012
# 6        SBIN      562.0       514.0       511.0   433.534210    615.549988
# 7   SUNPHARMA      960.0       906.0       900.0   728.985413   1051.949951
# C:\Users\MANAV\AppData\Local\Temp\ipykernel_10536\3818606084.py:108: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# C:\Users\MANAV\AppData\Local\Programs\Python\Python39\lib\site-packages\yahoo_fin\stock_info.py:295: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = tables[0].append(tables[1])
# C:\Users\MANAV\AppData\Local\Programs\Python\Python39\lib\site-packages\yahoo_fin\stock_info.py:302: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(quote_price)
# [*********************100%***********************]  1 of 1 completed
# C:\Users\MANAV\AppData\Local\Programs\Python\Python39\lib\site-packages\yahoo_fin\stock_info.py:295: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = tables[0].append(tables[1])
# C:\Users\MANAV\AppData\Local\Programs\Python\Python39\lib\site-packages\yahoo_fin\stock_info.py:302: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(quote_price)
# [*********************100%***********************]  1 of 1 completed
# C:\Users\MANAV\AppData\Local\Programs\Python\Python39\lib\site-packages\yahoo_fin\stock_info.py:295: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = tables[0].append(tables[1])
# C:\Users\MANAV\AppData\Local\Programs\Python\Python39\lib\site-packages\yahoo_fin\stock_info.py:302: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(quote_price)
# [*********************100%***********************]  1 of 1 completed
# C:\Users\MANAV\AppData\Local\Programs\Python\Python39\lib\site-packages\yahoo_fin\stock_info.py:295: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = tables[0].append(tables[1])
# C:\Users\MANAV\AppData\Local\Programs\Python\Python39\lib\site-packages\yahoo_fin\stock_info.py:302: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(quote_price)
# [*********************100%***********************]  1 of 1 completed
# C:\Users\MANAV\AppData\Local\Programs\Python\Python39\lib\site-packages\yahoo_fin\stock_info.py:295: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = tables[0].append(tables[1])
# C:\Users\MANAV\AppData\Local\Programs\Python\Python39\lib\site-packages\yahoo_fin\stock_info.py:302: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(quote_price)
# [*********************100%***********************]  1 of 1 completed
# C:\Users\MANAV\AppData\Local\Programs\Python\Python39\lib\site-packages\yahoo_fin\stock_info.py:295: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = tables[0].append(tables[1])
# C:\Users\MANAV\AppData\Local\Programs\Python\Python39\lib\site-packages\yahoo_fin\stock_info.py:302: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(quote_price)
# [*********************100%***********************]  1 of 1 completed
# C:\Users\MANAV\AppData\Local\Programs\Python\Python39\lib\site-packages\yahoo_fin\stock_info.py:295: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = tables[0].append(tables[1])
# C:\Users\MANAV\AppData\Local\Programs\Python\Python39\lib\site-packages\yahoo_fin\stock_info.py:302: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(quote_price)
# [*********************100%***********************]  1 of 1 completed
# C:\Users\MANAV\AppData\Local\Programs\Python\Python39\lib\site-packages\yahoo_fin\stock_info.py:295: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = tables[0].append(tables[1])
# C:\Users\MANAV\AppData\Local\Programs\Python\Python39\lib\site-packages\yahoo_fin\stock_info.py:302: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(quote_price)

# %%
# Out:
# C:\Users\MANAV\AppData\Local\Temp\ipykernel_10536\3330498206.py:3: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %%
plt.figure(figsize=(20, 20))
plt.xlabel("Stocks")
plt.ylabel("Current Price")
plt.title("Selected Stocks Current price")
plt.bar(stocks, currentPrice, align='center', width=0.5, color='green')
plt.savefig("C:\\Users\\MANAV\\Desktop\\Stock Screener\\graph.png")

# %%
plt.figure(figsize=(20, 20))
plt.xlabel("Stocks")
plt.ylabel("Market Cap")
plt.title("Selected Stocks Market Cap(in Millions)")
plt.bar(stocks, Market_Cap_in_mil, width=0.5, color='yellow')
plt.savefig("C:\\Users\\MANAV\\Desktop\\Stock Screener\\graph1.png")

# %%
plt.figure(figsize=(20, 20))
plt.xlabel("Stocks")
plt.ylabel("PE Ratio")
plt.title("Selected Stocks PE Ratio")
plt.bar(stocks, PE_Ratio, width=0.5, color='red')
plt.savefig("C:\\Users\\MANAV\\Desktop\\Stock Screener\\graph2.png")

# %%
print(currentPrice)
# Out:
# [888.9000244140625, 837.2999877929688, 4106.0498046875]

# %%
print(currentPrice)
# Out:
# [4106.0498046875, 4106.0498046875, 4106.0498046875, 4106.0498046875, 4106.0498046875, 4106.0498046875, 4106.0498046875, 4106.0498046875, 4106.0498046875]

# %%
print(df1.Close[-1])
# Out:
# 4106.0498046875
